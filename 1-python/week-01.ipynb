# %% [markdown]
# # Week 01

# %% [markdown]
# ### Basics

# %%
2+2
# Out:
# 4

# %%
5+
# Out:
#   Cell In[4], line 1
#     5+
#       ^
# SyntaxError: invalid syntax

# %%
string = 'Hello'
print(string)
# Out:
# Hello

# %%
'Alice' + 'Bob'
# Out:
# 'AliceBob'

# %%
'Alice '*3
# Out:
# 'Alice Alice Alice '

# %%
spam = 42
spam
# Out:
# 42

# %%
spam = 'Goodbye'
spam
# Out:
# 'Goodbye'

# %% [markdown]
# it's a convention to start your variable's name with a lowercase letter

# %% [markdown]
# #### This program says hello and ask for my name

# %%
print('Hello')
print('What is your name')
my_name = input()
print('It is good to know you '+my_name)
print('What is your age?')
my_age = input('>') #the input() function always return a string
print('You will be '+ str(int(my_age)+1) + ' in one year!')
# Out:
# Hello
# What is your name
#  anas
# It is good to know you anas
# What is your age?
# > 12
# You will be 13 in one year!

# %%
int(12)
# Out:
# 12

# %%
int('9.99')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 int('9.99')
#
# ValueError: invalid literal for int() with base 10: '9.99'

# %%
42 == '42'

# %%
type(my_name) #helps you find the right type of a variable

# %%
round(3.51)
# Out:
# 4

# %%
round(3.49)
# Out:
# 3

# %%
round(3.145, 2) #rounded to two digits after .
# Out:
# 3.15

# %%
abs(-2.3)
# Out:
# 2.3

# %%
True
# Out:
# True

# %%
print(42 != 42)
print(2 < 3)
print(4 < 2)
print('hello' == 'Hello')
# Out:
# False
# True
# False
# False

# %% [markdown]
# #### integer and float are the same, integer and str are not!

# %%
print(42 == 42.0)
print(42 == '42')
# Out:
# True
# False

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
(5<4) and (6<5)
# Out:
# False

# %% [markdown]
# ### Conditions

# %%
username = input('Enter your username : ')
password = input('Enter your password : ')
if (username == 'Anas' and password == 'admin123'):
    print('Successful login!')
elif len(username) < 5:
    print('Authorized username.')
else:
    print('Please enter correct credentials.')
# Out:
# Enter your username :  adm
# Enter your password :  adm
# Authorized username.

# %% [markdown]
# elif is checked only if all the previous if are false. We stop when the current elif is true, the following line are ignored.

# %% [markdown]
# ### Loops

# %%
name = 'Anas'
while True:
    your_name = input('>')
    if (your_name == name):
        print("Good to see you")
        break
    print('Go away!')
# Out:
# > y
# Go away!
# > Anas
# Good to see you
